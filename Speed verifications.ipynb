# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rc('text', usetex=True)
#plt.rc('font',**{'family':'sans-serif','sans-serif':[]})
plt.rcParams['text.usetex'] = True

#set font sizes
SMALL_SIZE = 15
MEDIUM_SIZE = 15

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize

timestep = 0.01
eps = 0.03
dx = 0.0613592315
estro = 101
Domain_size = 20*np.pi

# %%
1. Compute theta_T for u_0. Compare speed of eps = 0.03 to time step from equation (use Riemann integral) np.diff and divide by dx
2. Collision experiments compare with correct speed and plot xt.data and norm file
3. Compute norm diff plots
4. check -0.63 r value
5. Check bound state speed and compare with formula
6. Check both sides of Maxwell point with larger asymmetric solutions
    Make sure eps=0 for this
	also vary r test how far the smallest pattern esp. exists
	symmetric with 1 peak up and down vs. asymmetric 1 peak
	start with smaller structure collisions and move up later	
	keep either symmetric or antisymmetric constant and vary
Use 20pi domain size instead of 40pi
Keep everything at dt = 0.01
# Out:
#   Input In [4]
#     1. Compute theta_T for u_0. Compare speed of eps = 0.03 to time step from equation (use Riemann integral) np.diff and divide by dx
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Singular 1 peak speed

# %%
#Formula calculation:
    #Remember about estro, domain size, and time step
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/1/xt_r_-0.65_1.dat")
campo_file = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/1/campo_speed_test.dat")
norm_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/1/norm_r_-0.65_1.dat")


t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx

#From data drawing:
m1 = 2.278 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data)
plt.plot(x,m1*(x-23),'k--')
#plt.ylim([0, 20])
plt.show()

#Note I'm scaling by estro at the end as this makes the graph easier to fit with the line
speed = 1/(m1*estro)
print(speed)


#Speed verification:

div_u = np.diff(campo_file)/dx
three = div_u**3
two = div_u**2
sum3 = np.sum(dx*three)
sum2 = np.sum(dx*two)

speed_verification = -1*eps*sum3/sum2
print(speed_verification)
# Out:
# 0.004346352106676866
# 0.004363253546710517

# %% [markdown]
# # Bound states

# %%
#r = -0.6375


#Formula calculation:
    #Remember about estro, domain size, and time step
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/bound_states_+s3_-a2/r6375/xt6375sp.dat")
campo_file = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/bound_states_+s3_-a2/r6375/campo6375.dat")

t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx

#From data drawing:
m1 = -13.9 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data)
plt.plot(x,m1*(x-23),'k--')
plt.ylim([0, 20])
plt.show()

#Note I'm scaling by estro at the end as this makes the graph easier to fit with the line
speed = 1/(m1*estro)
print(speed)


#Speed verification:

div_u = np.diff(campo_file)/dx
three = div_u**3
two = div_u**2
sum3 = np.sum(dx*three)
sum2 = np.sum(dx*two)

speed_verification = -1*eps*sum3/sum2
print(speed_verification)
# Out:
# -0.0007123014459719353
# -0.0007055407104216775

# %%
#r = -0.64

#Formula calculation:
    #Remember about estro, domain size, and time step
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/bound_states_1-1/r64/xt64sp.dat")
campo_file = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/bound_states_1-1/r64/campo64.dat")

t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx

#From data drawing:
m1 = -9.5 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data)
plt.plot(x,m1*(x-23),'k--')
plt.ylim([0, 20])
plt.show()

#Note I'm scaling by estro at the end as this makes the graph easier to fit with the line
speed = 1/(m1*estro)
print(speed)


#Speed verification:

div_u = np.diff(campo_file)/dx
three = div_u**3
two = div_u**2
sum3 = np.sum(dx*three)
sum2 = np.sum(dx*two)

speed_verification = -1*eps*sum3/sum2
print(speed_verification)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [8], in <cell line: 5>()
#       1 #r = -0.64
#       2
#       3 #Formula calculation:
#       4     #Remember about estro, domain size, and time step
# ----> 5 xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/bound_states_1-1/r64/xt64sp.dat")
#       6 campo_file = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/bound_states_1-1/r64/campo64.dat")
#       8 t = np.arange(len(xt_data[:,0]))*timestep
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/lib/npyio.py:1042, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1040     fname = os_fspath(fname)
#    1041 if _is_string_like(fname):
# -> 1042     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
# ...

# %%
#r = -0.6425


#Formula calculation:
    #Remember about estro, domain size, and time step
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/bound_states_+s3_-a2/r6425/xt6425sp.dat")
campo_file = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/bound_states_+s3_-a2/r6425/campo6425.dat")

t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx

#From data drawing:
m1 = -10.9 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data)
plt.plot(x,m1*(x-23),'k--')
plt.ylim([0, 20])
plt.show()

#Note I'm scaling by estro at the end as this makes the graph easier to fit with the line
speed = 1/(m1*estro)
print(speed)


#Speed verification:

div_u = np.diff(campo_file)/dx
three = div_u**3
two = div_u**2
sum3 = np.sum(dx*three)
sum2 = np.sum(dx*two)

speed_verification = -1*eps*sum3/sum2
print(speed_verification)
# Out:
# -0.0009083477155054955
# -0.0009132093839742976

# %% [markdown]
# # Confirmation of formula (varied eps)

# %%
#Used same campo file, r=-0.64
epsilons = np.array([0.01, 0.03, 0.05, 0.07, 0.08])
e =0.09, 0.1, 0.11, 0.12, 0.13, 0.15
observed = []

campo_file = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/-a2/e01/campo.dat")


#Speed verification:

div_u = np.diff(campo_file)/dx
three = div_u**3
two = div_u**2
sum3 = np.sum(dx*three)
sum2 = np.sum(dx*two)

formula = -1*epsilons*sum3/sum2

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/-a2/e01/xt01.dat")
t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx
m1 = -7.1 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data)
plt.plot(x,m1*(x-35),'k--')
plt.ylim([0, 20])
speed = 1/(m1*estro)
observed.append(speed)

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/-a2/e03/xt03.dat")
t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx
m3 = -2.4 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data)
plt.plot(x,m3*(x-35),'k--')
plt.ylim([0, 20])
plt.show()
speed = 1/(m3*estro)
observed.append(speed)

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/-a2/e05/xt05.dat")
t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx
m5 = -1.45 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data)
plt.plot(x,m5*(x-35),'k--')
plt.ylim([0, 20])
plt.show()
speed = 1/(m5*estro)
observed.append(speed)

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/-a2/e07/xt07.dat")
t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx
m7 = -1 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data)
plt.plot(x,m7*(x-35),'k--')
plt.ylim([0, 20])
plt.show()
speed = 1/(m7*estro)
observed.append(speed)

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/-a2/e08/xt08.dat")
t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx
m8 = -0.9 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data)
plt.plot(x,m8*(x-35),'k--')
plt.ylim([0, 20])
plt.show()
speed = 1/(m8*estro)
observed.append(speed)

# %%
print(observed)
print(formula)
# Out:
# [-0.0013945056477478737, -0.004125412541254126, -0.006828269033799932, -0.009900990099009901, -0.011001100110011]
# [-0.00138847 -0.0041654  -0.00694233 -0.00971927 -0.01110774]

# %%
#plt.scatter(epsilons, formula, 2, label = "from theory")
plt.scatter(epsilons, observed, 20, 'r', label = r"\textrm{Velocities from DNS}")
theory = np.poly1d(np.polyfit(epsilons, formula, 1)) 
dns = np.poly1d(np.polyfit(epsilons, observed, 1)) 
plt.plot(epsilons, theory(epsilons), '--k', label = r"\textrm{Theoretical prediction}")
print(theory)
plt.xlabel("$\epsilon$")
plt.ylabel(r"\textrm{c (Velocity)}")
plt.legend()
plt.tight_layout()
plt.savefig('speed_verifications.pdf',dpi = 300)
# Out:
#
# -0.1388 x - 2.051e-18

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # for a4

# %%
res = 8192
dt = 0.01
eps = 0.03
estro = 101
domain_size = 40*np.pi
dx = domain_size/res
print(dx)
L = domain_size;
n = res
timestep = dt
# Out:
# 0.015339807878856412

# %%
#Used same campo file, 
epsilons = np.array([0, 0.01, 0.03, 0.05, 0.07, 0.09, 0.1, 0.11, 0.12, 0.125, 0.13])
observed = {} 
e = np.array(['01', '03', '05', '07', '09', '1', '11', '12', '12.5', '13'])
campo_file = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/-a4/eps03/campo.dat")
r = -0.66

#Speed verification:

div_u = np.diff(campo_file)/dx
three = div_u**3
two = div_u**2
sum3 = np.sum(dx*three)
sum2 = np.sum(dx*two)

formula = -1*epsilons*sum3/sum2
theoretical = []

for i in range(len(e)):
    campo_file = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/-a4/eps{}/campo.dat".format(e[i]))
    div_u = np.diff(campo_file)/dx
    three = div_u**3
    two = div_u**2
    sum3 = np.sum(dx*three)
    sum2 = np.sum(dx*two)
    theoretical.append(-1*epsilons[i]*sum3/sum2)

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/-a4/eps01/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx
m1 = -15 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 5)
plt.plot(x,m1*(x-80)-3.5,'k--')
plt.ylim([0, 7])
plt.xlim([79, 81])
speed = 1/(m1*estro)
observed.update({0.01: speed})

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/-a4/eps03/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx
m1 = -5 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 5)
plt.plot(x,m1*(x-80)-1.5,'k--')
plt.ylim([0, 7])
plt.xlim([78, 81])
speed = 1/(m1*estro)
observed.update({0.03: speed})

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/-a4/eps05/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx
m1 = -3 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 5)
plt.plot(x,m1*(x-80.4)-2.5,'k--')
plt.ylim([0, 7])
plt.xlim([75, 81])
speed = 1/(m1*estro)
observed.update({0.05: speed})

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/-a4/eps07/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx
m1 = -2.15 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 5)
plt.plot(x,m1*(x-80.2)-1.5,'k--')
plt.ylim([0, 7.5])
#plt.xlim([75, 81])
speed = 1/(m1*estro)
observed.update({0.07: speed})

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/-a4/eps09/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx
m1 = -1.68 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 5)
plt.plot(x,m1*(x-80.05)-2,'k--')
plt.ylim([0, 6])
#plt.xlim([76, 81])
speed = 1/(m1*estro)
observed.update({0.09: speed})

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/-a4/eps1/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx
m1 = -1.52#Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 5)
plt.plot(x,m1*(x-80)+2.1,'k--')
plt.ylim([0, 7])
plt.xlim([76, 81])
speed = 1/(m1*estro)
observed.update({0.1:speed})

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/-a4/eps11/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx
m1 = -1.3925 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 5)
plt.plot(x,m1*(x-80)+3,'k--')
#plt.ylim([0, 17])
#plt.xlim([75, 81])
speed = 1/(m1*estro)
observed.update({0.11: speed})

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/-a4/eps12/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx
m1 = -1.27 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 30)
plt.plot(x,m1*(x-81.5),'k--')
plt.ylim([2, 3])
plt.xlim([79.8, 80])
speed = 1/(m1*estro)
observed.update({0.12 : speed})

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/-a4/eps13/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx
m1 = -1.25 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 5)
plt.plot(x,m1*(x-82),'k--')
plt.ylim([0, 8])
plt.xlim([76, 83])
speed = 1/(m1*estro)
observed.update({0.13: speed})

# %%
timestep2 = 0.001
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/-a4/eps12v2/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep2
x = np.arange(len(xt_data[0,:]))*dx
m1 = -1.2825 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 5)
plt.plot(x,m1*(x-81)-0.2,'k--')
plt.ylim([0, 8])
plt.xlim([75, 82])
speed = 1/(m1*estro)
print(speed)
observed.update({0.12: speed})
# Out:
# -0.007720070252639299

# %%
timestep2 = 0.001
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/-a4/eps12.5/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep2
x = np.arange(len(xt_data[0,:]))*dx
m1 = -1.25 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 5)
plt.plot(x,m1*(x-81),'k--')
plt.ylim([0, 10])
plt.xlim([76, 79.5])
speed = 1/(m1*estro)
observed.update({0.125: speed})

# %%
timestep2 = 0.001
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/-a4/eps13v2/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep2
x = np.arange(len(xt_data[0,:]))*dx
m1 = -1.235 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 5)
plt.plot(x,m1*(x-81)-0.25,'k--')
plt.ylim([0, 6.5])
#plt.xlim([76, 81])
speed = 1/(m1*estro)
print(speed)
print(observed[0.13])
observed.update({0.13: speed})
# Out:
# -0.008016996031586964
# -0.007920792079207921

# %%
#print(theoretical)
c_continuation = -1*np.loadtxt('ahrm2cepsrc.txt')
epsilon_continuation = np.loadtxt('ahrm2cepsreps.txt')

theory = np.poly1d(np.polyfit(epsilons, formula, 1)) 
dns = np.poly1d(np.polyfit(list(observed.keys()), list(observed.values()), 1)) 
plt.plot(epsilons, theory(epsilons), '-', color = 'cornflowerblue', label = r"\textrm{Theory}", zorder=1)
#plt.scatter(epsilon_continuation, continuation_1, 20, color = 'green', label = r'\textrm{Continuation, first sent}')
#plt.scatter(epsilon_continuation, continuation_2, 20, color = 'blue', label = r'\textrm{Continuation, second sent}')
plt.plot(epsilon_continuation, c_continuation, color = 'green', linestyle = '-.', label = r'\textrm{Continuation}', zorder=2)
plt.scatter(observed.keys(), observed.values(), 20, 'r', label = r'\textrm{DNS}', zorder=3)

plt.xlabel("$\epsilon$")
plt.ylabel(r"\textrm{c}")
plt.legend()
plt.tight_layout()
plt.savefig('speed_verifications.svg',dpi = 300)

# %% [markdown]
# # Resolution: 2048

# %%
res = 2048
dt = 0.01
eps = 0.03
estro = 101
domain_size = 40*np.pi
dx = domain_size/res
print(dx)
L = domain_size;
n = res
timestep = dt
# Out:
# 0.06135923151542565

# %%
#Used same campo file, 
epsilons = np.array([0, 0.01, 0.03, 0.05, 0.07, 0.09, 0.1, 0.11, 0.12, 0.125, 0.13])
observed2 = {} 
e = np.array(['01', '03', '05', '07', '09', '1', '11', '12', '12.5', '13'])
campo_file = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/res2048/-a4/eps03/campo.dat")
r = -0.66

#Speed verification:

div_u = np.diff(campo_file)/dx
three = div_u**3
two = div_u**2
sum3 = np.sum(dx*three)
sum2 = np.sum(dx*two)

formula = -1*epsilons*sum3/sum2
theoretical2 = []

for i in range(len(e)):
    campo_file = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/res2048/-a4/eps{}/campo.dat".format(e[i]))
    div_u = np.diff(campo_file)/dx
    three = div_u**3
    two = div_u**2
    sum3 = np.sum(dx*three)
    sum2 = np.sum(dx*two)
    theoretical2.append(-1*epsilons[i]*sum3/sum2)

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/res2048/-a4/eps01/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx
m1 = -15 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 5)
plt.plot(x,m1*(x-90)+12.4,'k--')
plt.ylim([0, 47])
plt.xlim([87, 91])
speed = 1/(m1*estro)
observed2.update({0.01: speed})

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/res2048/-a4/eps03/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx
m1 = -5 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 5)
plt.plot(x,m1*(x-90)+2.3,'k--')
plt.ylim([0, 47])
plt.xlim([87, 92])
speed = 1/(m1*estro)
observed2.update({0.03: speed})

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/res2048/-a4/eps05/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx
m1 = -3 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 5)
plt.plot(x,m1*(x-90)+2.3,'k--')
plt.ylim([0, 47])
plt.xlim([87, 92])
speed = 1/(m1*estro)
observed2.update({0.05: speed})

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/res2048/-a4/eps07/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx
m1 = -2.15 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 5)
plt.plot(x,m1*(x-90)+2.3,'k--')
plt.ylim([0, 47])
plt.xlim([87, 92])
speed = 1/(m1*estro)
observed2.update({0.07: speed})

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/res2048/-a4/eps09/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx
m1 = -1.68 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 5)
plt.plot(x,m1*(x-90)+2.3,'k--')
plt.ylim([0, 47])
plt.xlim([87, 92])
speed = 1/(m1*estro)
observed2.update({0.09: speed})

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/res2048/-a4/eps1/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx
m1 = -1.52#Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 5)
plt.plot(x,m1*(x-90)+2.3,'k--')
plt.ylim([0, 47])
plt.xlim([87, 92])
speed = 1/(m1*estro)
observed2.update({0.1:speed})

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/res2048/-a4/eps11/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep
x = np.arange(len(xt_data[0,:]))*dx
m1 = -1.3925 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 5)
plt.plot(x,m1*(x-90)+2.3,'k--')
plt.ylim([0, 47])
plt.xlim([87, 92])
speed = 1/(m1*estro)
observed2.update({0.11: speed})

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/res2048/-a4/eps12/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep2
x = np.arange(len(xt_data[0,:]))*dx
m1 = -1.2825 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 5)
plt.plot(x,m1*(x-90)+2.3,'k--')
plt.ylim([0, 11])
plt.xlim([87, 92])
speed = 1/(m1*estro)
observed2.update({0.12 : speed})

# %%
timestep2 = 0.001
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/res2048/-a4/eps12.5/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep2
x = np.arange(len(xt_data[0,:]))*dx
m1 = -1.25 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 5)
plt.plot(x,m1*(x-90)+2.3,'k--')
plt.ylim([0, 11])
plt.xlim([87, 92])
speed = 1/(m1*estro)
observed2.update({0.125: speed})

# %%
xt_data = np.loadtxt("/Users/mathiraja/Desktop/speed_testing/res2048/-a4/eps13/xt.dat")
t = np.arange(len(xt_data[:,0]))*timestep2
x = np.arange(len(xt_data[0,:]))*dx
m1 = -1.235 #Approximate value of slope based on the graph
X,T = np.meshgrid(x,t)
plt.contourf(X,T,xt_data, 5)
plt.plot(x,m1*(x-90)+2.2,'k--')
plt.ylim([0, 11])
plt.xlim([87, 92])
speed = 1/(m1*estro)
observed2.update({0.13: speed})

# %%
#print(theoretical)
c_continuation = -1*np.loadtxt('ahrm2cepsrc.txt')
epsilon_continuation = np.loadtxt('ahrm2cepsreps.txt')

theory = np.poly1d(np.polyfit(epsilons, formula, 1)) 
dns = np.poly1d(np.polyfit(list(observed.keys()), list(observed.values()), 1)) 
plt.plot(epsilons, theory(epsilons), '-', color = 'cornflowerblue', label = r"\textrm{Theory}", zorder=1)
#plt.scatter(epsilon_continuation, continuation_1, 20, color = 'green', label = r'\textrm{Continuation, first sent}')
#plt.scatter(epsilon_continuation, continuation_2, 20, color = 'blue', label = r'\textrm{Continuation, second sent}')
plt.plot(epsilon_continuation, c_continuation, color = 'green', linestyle = '-.', label = r'\textrm{Continuation}', zorder=2)
plt.scatter(observed.keys(), observed.values(), 20, 'r', label = r'\textrm{DNS}', zorder=3)
plt.scatter(observed2.keys(), observed2.values(), 20, 'pink', label = r'\textrm{DNS}', zorder=4)

plt.xlabel("$\epsilon$")
plt.ylabel(r"\textrm{c}")
plt.legend()
plt.tight_layout()
plt.savefig('speed_verifications.svg',dpi = 300)
